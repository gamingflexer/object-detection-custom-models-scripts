# %% [markdown]
# # Installations

# %%
# !pip install gdown -q
# !git clone https://github.com/facebookresearch/detectron2.git
# %cd detectron2
# !pip install -e . -q
# %cd ..
# Out:
# Cloning into 'detectron2'...
# remote: Enumerating objects: 14608, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 14608 (delta 5), reused 16 (delta 1), pack-reused 14583
# Receiving objects: 100% (14608/14608), 5.97 MiB | 12.39 MiB/s, done.
# Resolving deltas: 100% (10562/10562), done.
# /content/detectron2
#      |████████████████████████████████| 50 kB 3.4 MB/s
#      |████████████████████████████████| 79 kB 6.5 MB/s
#      |████████████████████████████████| 151 kB 56.9 MB/s
#      |████████████████████████████████| 1.4 MB 47.6 MB/s
#      |████████████████████████████████| 548 kB 48.2 MB/s
#      |████████████████████████████████| 248 kB 63.1 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 843 kB 34.3 MB/s
# ...

# %% [markdown]
# #YOLO TO COCO

# %%
#download your yolo dataset
# !gdown 1w9D2cXpx-znPU379nVeZJyd5ZfkbJYW9
# !unzip /content/yolo_dataset_base.zip

# %%
# !git clone https://github.com/Taeyoung96/Yolo-to-COCO-format-converter.git
# %cd Yolo-to-COCO-format-converter
#change main.py classes
# Out:
# Cloning into 'Yolo-to-COCO-format-converter'...
# remote: Enumerating objects: 255, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 255 (delta 34), reused 29 (delta 24), pack-reused 207
# Receiving objects: 100% (255/255), 30.92 MiB | 25.39 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# /content/Yolo-to-COCO-format-converter

# %%
#conversion
# !python main.py --path /content/yolo_dataset/ --output train
# Out:
# Start!
# Processing 8 ...Finished!

# %% [markdown]
# # TRAIN

# %%
# %cd /content/
# !mkdir /content/coco_dataset/
# Out:
# /content

# %%
# !git clone https://github.com/Layout-Parser/layout-model-training.git
# %cd /content/layout-model-training
# Out:
# /content/layout-model-training

# %%
# !pip install -r /content/layout-model-training/requirements.txt

# %%
# !python /content/layout-model-training/utils/cocosplit.py --annotation-path "/content/Yolo-to-COCO-format-converter/output/train" --train  "/content/coco_dataset/train.json" --test "/content/coco_dataset/test.json" --split-ratio 0.8
# Out:
# Saved 7 entries in /content/coc_dataset/train.json and 2 in /content/coc_dataset/test.json

# %%
# !wget https://www.dropbox.com/s/nau5ut6zgthunil/config.yaml?dl=1
# Out:
# --2022-11-16 02:56:35--  https://www.dropbox.com/s/nau5ut6zgthunil/config.yaml?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/nau5ut6zgthunil/config.yaml [following]
# --2022-11-16 02:56:36--  https://www.dropbox.com/s/dl/nau5ut6zgthunil/config.yaml
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uccf4320b9fb8a2ed5591d87c42c.dl.dropboxusercontent.com/cd/0/get/Bw3jv3S804kX8nz_6KfRrJIg7MI2VoldABVdh3PPyiA-yTfYyYCzCuYDgeFlhXARCvh3CdaUQNl5Sr7PwIF3dXanPucRbvUYJYetYo0Uhdble94Z_UA2Hz7dPyfT_mBJRrW3JWMxE1l6sFO_HYLOKJwNW7cgUHD3DLj9rE0q56LTzSM07tAifJAnxwmBMPPFfd0/file?dl=1# [following]
# ...

# %%
# !wget https://www.dropbox.com/s/57zjbwv6gh3srry/model_final.pth?dl=1
# !mv model_final.pth?dl=1 model_final.pth
# Out:
# --2022-11-16 02:57:57--  https://www.dropbox.com/s/57zjbwv6gh3srry/model_final.pth?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/57zjbwv6gh3srry/model_final.pth [following]
# --2022-11-16 02:57:58--  https://www.dropbox.com/s/dl/57zjbwv6gh3srry/model_final.pth
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc531cd0320bde74cbebc7660c8f.dl.dropboxusercontent.com/cd/0/get/Bw2gO6qQgz3QBRMhRF-kEgo32KLdt9u6Glj5NVxca04rrLOqCSb5XQ17b8mRqLfzzf8G568BP8roEhzbSPJSIYgMKTy9a_zSN36k9Rl50rkLCOshy6SNgwR0y9EIGe8U2O6uWUInbqjF7P7PrMSnK-Fq2kgJAlh0xdqPZnSVOVfXEk843StOLP755KtmDGhPB3g/file?dl=1# [following]
# ...

# %%
#save model path
# !mkdir /content/model_wieghts

# %%
#add 138 line cfg.MODEL.DEVICE = 'cpu' for cpu in train_net.py
# !python /content/layout-model-training/tools/train_net.py --dataset_name "my_dataset" --json_annotation_train "/content/coco_dataset/train.json" --image_path_train "/content/yolo_dataset" --json_annotation_val "/content/coco_dataset/test.json" --image_path_val "/content/yolo_dataset" --config-file "/content/layout-model-training/config.yaml?dl=1" MODEL.WEIGHTS "/content/layout-model-training/model_final.pth" OUTPUT_DIR "/content/model_wieghts" MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE 2 SOLVER.CHECKPOINT_PERIOD 20000 SOLVER.MAX_ITER 80000 SOLVER.IMS_PER_BATCH 2 INPUT.RANDOM_FLIP "vertical"
# Out:
# Command Line Args: Namespace(config_file='/content/layout-model-training/config.yaml?dl=1', dataset_name='my_dataset', dist_url='tcp://127.0.0.1:49152', eval_only=False, image_path_train='/content/yolo_dataset', image_path_val='/content/yolo_dataset', json_annotation_train='/content/coc_dataset/train.json', json_annotation_val='/content/coc_dataset/test.json', machine_rank=0, num_gpus=1, num_machines=1, opts=['MODEL.WEIGHTS', '/content/layout-model-training/model_final.pth', 'OUTPUT_DIR', '/content/model_wieghts', 'MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE', '2', 'SOLVER.CHECKPOINT_PERIOD', '20000', 'SOLVER.MAX_ITER', '80000', 'SOLVER.IMS_PER_BATCH', '2', 'INPUT.RANDOM_FLIP', 'vertical'], resume=False)
# [11/16 03:11:50 detectron2]: Rank of current process: 0. World size: 1
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# [11/16 03:11:51 detectron2]: Environment info:
# ---------------------  ----------------------------------------------------------------
# ...

# %% [markdown]
# #Inference

# %%
model = lp.Detectron2LayoutModel(r"path\to\finetuned\config.yaml",
                                 r"path\to\finetuned\model_final.pth",
                                 extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.8],
                                 label_map=custom_label_map)
